# %% [markdown]
# ## Импорты

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Задание 1
#
# Загрузите дневные котировки 3 акций (Apple, Google, Facebook) из открытых источников за последние 10 лет:
#
#    - https://www.alphavantage.co/documentation/
#    - https://blog.quandl.com/api-for-stock-data
#    - https://www.quora.com/What-are-some-good-APIs-to-get-real-time-stock-quotes
#
# Для однозначности используйте цены закрытия

# %% [markdown]
# **Акции Apple**

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=AAPL&apikey=8HDT2N2QSWWH0Q5D'
r = requests.get(url)
data_apple = r.json()

print(data_apple)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'AAPL', '3. Last Refreshed': '2022-08-26', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-08-26': {'1. open': '170.5700', '2. high': '171.0500', '3. low': '163.5600', '4. close': '163.6200', '5. volume': '78960980'}, '2022-08-25': {'1. open': '168.7800', '2. high': '170.1400', '3. low': '168.3500', '4. close': '170.0300', '5. volume': '51218209'}, '2022-08-24': {'1. open': '167.3200', '2. high': '168.1100', '3. low': '166.2450', '4. close': '167.5300', '5. volume': '53841524'}, '2022-08-23': {'1. open': '167.0800', '2. high': '168.7100', '3. low': '166.6500', '4. close': '167.2300', '5. volume': '54147079'}, '2022-08-22': {'1. open': '169.6900', '2. high': '169.8600', '3. low': '167.1350', '4. close': '167.5700', '5. volume': '69026809'}, '2022-08-19': {'1. open': '173.0300', '2. high': '173.7400', '3. low': '171.3101', '4. close': '171.5200'
# ...

# %%
apple = pd.DataFrame(data_apple['Time Series (Daily)']).T
apple
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2022-08-26  170.5700  171.0500  163.5600  163.6200  78960980
# 2022-08-25  168.7800  170.1400  168.3500  170.0300  51218209
# 2022-08-24  167.3200  168.1100  166.2450  167.5300  53841524
# 2022-08-23  167.0800  168.7100  166.6500  167.2300  54147079
# 2022-08-22  169.6900  169.8600  167.1350  167.5700  69026809
# ...              ...       ...       ...       ...       ...
# 1999-11-05   84.6200   88.3700   84.0000   88.3100   3721500
# 1999-11-04   82.0600   85.3700   80.6200   83.6200   3384700
# 1999-11-03   81.6200   83.2500   81.0000   81.5000   2932700
# 1999-11-02   78.0000   81.6900   77.3100   80.2500   3564600
# 1999-11-01   80.0000   80.6900   77.3700   77.6200   2487300
#
# [5743 rows x 5 columns]

# %%
apple.to_csv('data/apple.csv')

# %% [markdown]
# **Акции Google класса C**

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=GOOG&apikey=8HDT2N2QSWWH0Q5D'
r = requests.get(url)
data_google_c = r.json()

print(data_google_c)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'GOOG', '3. Last Refreshed': '2022-08-26', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-08-26': {'1. open': '115.8100', '2. high': '116.6000', '3. low': '111.2200', '4. close': '111.3000', '5. volume': '31698668'}, '2022-08-25': {'1. open': '115.1500', '2. high': '117.7800', '3. low': '115.0500', '4. close': '117.7000', '5. volume': '14874666'}, '2022-08-24': {'1. open': '114.4500', '2. high': '115.7171', '3. low': '113.7800', '4. close': '114.7000', '5. volume': '16051174'}, '2022-08-23': {'1. open': '114.3200', '2. high': '115.9300', '3. low': '114.3000', '4. close': '114.7700', '5. volume': '14390691'}, '2022-08-22': {'1. open': '116.1000', '2. high': '116.5000', '3. low': '114.6700', '4. close': '115.0700', '5. volume': '19316024'}, '2022-08-19': {'1. open': '119.8700', '2. high': '120.0000', '3. low': '117.6700', '4. close': '118.1200'
# ...

# %%
google_c = pd.DataFrame(data_google_c['Time Series (Daily)']).T
google_c
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2022-08-26  115.8100  116.6000  111.2200  111.3000  31698668
# 2022-08-25  115.1500  117.7800  115.0500  117.7000  14874666
# 2022-08-24  114.4500  115.7171  113.7800  114.7000  16051174
# 2022-08-23  114.3200  115.9300  114.3000  114.7700  14390691
# 2022-08-22  116.1000  116.5000  114.6700  115.0700  19316024
# ...              ...       ...       ...       ...       ...
# 2014-04-02  565.1060  604.8300  562.1900  567.0000    146700
# 2014-04-01  558.7100  568.4500  558.7100  567.1600      7900
# 2014-03-31  566.8900  567.0000  556.9300  556.9700     10800
# 2014-03-28  561.2000  566.4300  558.6700  559.9900     41100
# 2014-03-27  568.0000  568.0000  552.9200  558.4600     13100
#
# [2121 rows x 5 columns]

# %%
google_c.to_csv('data/google_c.csv')

# %% [markdown]
# **Акции Google класса А**

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=GOOGL&apikey=8HDT2N2QSWWH0Q5D'
r = requests.get(url)
data_google_a = r.json()

print(data_google_a)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'GOOGL', '3. Last Refreshed': '2022-08-26', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-08-26': {'1. open': '114.7200', '2. high': '115.1200', '3. low': '110.1900', '4. close': '110.3400', '5. volume': '37245697'}, '2022-08-25': {'1. open': '114.2350', '2. high': '116.7200', '3. low': '114.1100', '4. close': '116.6500', '5. volume': '16956794'}, '2022-08-24': {'1. open': '113.5000', '2. high': '114.7800', '3. low': '112.8701', '4. close': '113.6900', '5. volume': '17734624'}, '2022-08-23': {'1. open': '113.4750', '2. high': '115.0100', '3. low': '113.4300', '4. close': '113.8600', '5. volume': '15870373'}, '2022-08-22': {'1. open': '115.2000', '2. high': '115.6300', '3. low': '113.8500', '4. close': '114.2400', '5. volume': '21456648'}, '2022-08-19': {'1. open': '119.0600', '2. high': '119.1500', '3. low': '116.7600', '4. close': '117.2100
# ...

# %%
google_a = pd.DataFrame(data_google_a['Time Series (Daily)']).T
google_a
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2022-08-26  114.7200  115.1200  110.1900  110.3400  37245697
# 2022-08-25  114.2350  116.7200  114.1100  116.6500  16956794
# 2022-08-24  113.5000  114.7800  112.8701  113.6900  17734624
# 2022-08-23  113.4750  115.0100  113.4300  113.8600  15870373
# 2022-08-22  115.2000  115.6300  113.8500  114.2400  21456648
# ...              ...       ...       ...       ...       ...
# 2004-08-25  104.7600  108.0000  103.8800  106.0000   9188600
# 2004-08-24  111.2400  111.6000  103.5700  104.8700  15247300
# 2004-08-23  110.7600  113.4800  109.0500  109.4000  18256100
# 2004-08-20  101.0100  109.0800  100.5000  108.3100  22834300
# 2004-08-19  100.0100  104.0600   95.9600  100.3350  44659000
#
# [4538 rows x 5 columns]

# %%
google_a.to_csv('data/google_a.csv')

# %% [markdown]
# **Акции Facebook**

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=META&apikey=8HDT2N2QSWWH0Q5D'
r = requests.get(url)
data_fb = r.json()

print(data_fb)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'META', '3. Last Refreshed': '2022-08-26', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-08-26': {'1. open': '168.4800', '2. high': '170.9200', '3. low': '161.6726', '4. close': '161.7800', '5. volume': '24023633'}, '2022-08-25': {'1. open': '165.1800', '2. high': '168.8800', '3. low': '164.0200', '4. close': '168.7800', '5. volume': '15550514'}, '2022-08-24': {'1. open': '160.6000', '2. high': '165.4600', '3. low': '159.7700', '4. close': '163.2600', '5. volume': '20891481'}, '2022-08-23': {'1. open': '162.4800', '2. high': '165.0500', '3. low': '160.7000', '4. close': '161.1100', '5. volume': '18111777'}, '2022-08-22': {'1. open': '165.4900', '2. high': '165.4900', '3. low': '162.2600', '4. close': '163.0500', '5. volume': '19499711'}, '2022-08-19': {'1. open': '170.2000', '2. high': '172.3200', '3. low': '167.0500', '4. close': '167.9600'
# ...

# %%
facebook = pd.DataFrame(data_fb['Time Series (Daily)']).T
facebook
# Out:
#              1. open   2. high    3. low  4. close  5. volume
# 2022-08-26  168.4800  170.9200  161.6726  161.7800   24023633
# 2022-08-25  165.1800  168.8800  164.0200  168.7800   15550514
# 2022-08-24  160.6000  165.4600  159.7700  163.2600   20891481
# 2022-08-23  162.4800  165.0500  160.7000  161.1100   18111777
# 2022-08-22  165.4900  165.4900  162.2600  163.0500   19499711
# ...              ...       ...       ...       ...        ...
# 2012-05-24   32.9500   33.2100   31.7700   33.0300   50237200
# 2012-05-23   31.3700   32.5000   31.3600   32.0000   73600000
# 2012-05-22   32.6100   33.5900   30.9400   31.0000  101786600
# 2012-05-21   36.5300   36.6600   33.0000   34.0300  168192700
# 2012-05-18   42.0500   45.0000   38.0000   38.2318  573576400
#
# [2586 rows x 5 columns]

# %%
facebook.to_csv('data/facebook.csv')
